# %%
import segyio
import matplotlib.pyplot as plt
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg

def segy_file():
    segy_file = r'C:\Users\ashis\anaconda3\GP407\Untitled Folder\segyfiles\f11_02673_45Hz.segy'


# Open the SEG-Y file

#The ignore_geometry=True argument is used to handle SEG-Y files that might not conform to standard geometry specifications.
    with segyio.open(segy_file, ignore_geometry=True) as segyfile:   
        data = segyfile.trace.raw[:]
    #use the raw attribute of the segyfile.trace object to obtain the raw data.
    
    # Get the data dimensions
    num_traces = segyfile.tracecount                # gives you the total number of traces
    num_samples = segyfile.samples.size             # provides the number of samples per trace.
    
    # Create a plot
    plt.figure(figsize=(10, 6))
    
    # Plot the seismic data as an image
    plt.imshow(data.T, aspect='auto', cmap='seismic', extent=[0, num_traces, segyfile.samples[0], segyfile.samples[-1]])
#data.T transposes the data to match the standard orientation, 'auto' aspect ratio ensures correct scaling, cmap='seismic' sets the colormap to a seismic 
#color scheme (red-white-blue),and extent defines the extent of the image, including the x-axis (trace number) and y-axis (two-way time). 

    # Set labels and title
    plt.xlabel('Trace Number')
    plt.ylabel('Two-way Time (ms)')
    plt.title('SEG-Y Data Plot')
    
    # Show the plot
    plt.colorbar(label='Amplitude')       # adds a colorbar to the plot, which shows the amplitude scale
    plt.show()

# %%
from tkinter import *

# %%
root = Tk()
root.geometry("400x500")
f1 = Frame(root,borderwidth=8,bg="grey", relief=SUNKEN )
f1.pack(side=LEFT, fill="x",pady=4, anchor="nw")
l=Label(f1, text="Welcome to Segy files")
l.pack(pady=4, padx = 3)

b1 = Button(f1,fg = "red", text="Open Segy files", command=segy_file)
b1.pack(side=LEFT, padx =4)

root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\Users\ashis\anaconda3\Lib\tkinter\__init__.py", line 1948, in __call__
#     return self.func(*args)
#            ^^^^^^^^^^^^^^^^
#   File "C:\Users\ashis\AppData\Local\Temp\ipykernel_24272\1230146111.py", line 32, in segy_file
#     canvas = FigureCanvasTkAgg(fig, master=window)
#                                ^^^
# NameError: name 'fig' is not defined

# %%
# TO PLOT SEGY FILES
import segyio
import matplotlib.pyplot as plt

# Replace 'your_segy_file.segy' with the path to your SEG-Y file
segy_file = r'C:\Users\ashis\anaconda3\GP407\Untitled Folder\segyfiles\f11_02673_45Hz.segy'

# Open the SEG-Y file

#The ignore_geometry=True argument is used to handle SEG-Y files that might not conform to standard geometry specifications.
with segyio.open(segy_file, ignore_geometry=True) as segyfile:               
    # Get the seismic data
    data = segyfile.trace.raw[:]
    #use the raw attribute of the segyfile.trace object to obtain the raw data.
    
    # Get the data dimensions
    num_traces = segyfile.tracecount                # gives you the total number of traces
    num_samples = segyfile.samples.size             # provides the number of samples per trace.
    
    # Create a plot
    plt.figure(figsize=(10, 6))
    
    # Plot the seismic data as an image
    plt.imshow(data.T, aspect='auto', cmap='seismic', extent=[0, num_traces, segyfile.samples[0], segyfile.samples[-1]])
#data.T transposes the data to match the standard orientation, 'auto' aspect ratio ensures correct scaling, cmap='seismic' sets the colormap to a seismic 
#color scheme (red-white-blue),and extent defines the extent of the image, including the x-axis (trace number) and y-axis (two-way time). 

    # Set labels and title
    plt.xlabel('Trace Number')
    plt.ylabel('Two-way Time (ms)')
    plt.title('SEG-Y Data Plot')
    
    # Show the plot
    plt.colorbar(label='Amplitude')       # adds a colorbar to the plot, which shows the amplitude scale
    plt.show()

# %%
# Open the SEGY file in read mode
with segyio.open('f11_02673_45Hz.segy', 'r') as segyfile:

    # Read the file header
    file_header = segyfile.text[0]

    # Read the trace headers
    trace_headers = segyfile.header

    # Initialize an empty list to store the first signals
    first_signals = []

    # Loop over the traces
    for trace in segyfile.trace:

        # Get the first sample of the trace
        first_signal = trace[0]

        # Append it to the list
        first_signals.append(first_signal)

# Print the first signals
print(first_signals)
# Out:
# [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
